# %% [markdown]
# # Gradient descent - test

# %%
import sys
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data import

# %%
# Physical data
l = 10
tau = 5
dep = 2
# Numerical data
nx = 10
dx = l/nx
nt = 10
dt = tau/nt
x_grid = np.linspace(0,l,nx)
T_operator = l/nx*np.tri(nt, nx, 0, dtype=int)

# %%
# training data
sigma = 0.01
mu = l/2
x_dagger = (sigma*np.sqrt(2*np.pi))**-1*np.exp(-(x_grid-mu)**2/2*sigma**2)
x_init = np.zeros(nt)
y = T_operator.dot(x_dagger)

# %%
plt.plot(np.linspace(0,1,nx),x_dagger)

# %%
plt.plot(np.linspace(0,1,nt),y)

# %%
### Gradient descent

# %%
nstep = 
precision = 0.001
coeff = 0.02

error = np.zeros(nstep)
xk = np.zeros((nx,nstep))
xk[:,0] = x_init.copy()

for k in range(nstep-1):
    xk[:,k+1] = xk[:,k] \
    - coeff*(np.dot(T_operator.T,T_operator).dot(xk[:,k]) \
             - np.dot(T_operator.T,y))
    error[k] = l/nx*np.linalg.norm(x_dagger - xk[:,k])
    if error[k]<precision :
        print("objectif atteint en {} itérations".format(k))
# Out:
# objectif atteint en 1503 itérations
# objectif atteint en 1504 itérations
# objectif atteint en 1505 itérations
# objectif atteint en 1506 itérations
# objectif atteint en 1507 itérations
# objectif atteint en 1508 itérations
# objectif atteint en 1509 itérations
# objectif atteint en 1510 itérations
# objectif atteint en 1511 itérations
# objectif atteint en 1512 itérations
# objectif atteint en 1513 itérations
# objectif atteint en 1514 itérations
# objectif atteint en 1515 itérations
# objectif atteint en 1516 itérations
# objectif atteint en 1517 itérations
# objectif atteint en 1518 itérations
# objectif atteint en 1519 itérations
# objectif atteint en 1520 itérations
# objectif atteint en 1521 itérations
# objectif atteint en 1522 itérations
# objectif atteint en 1523 itérations
# objectif atteint en 1524 itérations
# objectif atteint en 1525 itérations
# objectif atteint en 1526 itérations
# objectif atteint en 1527 itérations
# objectif atteint en 1528 itérations
# objectif atteint en 1529 itérations
# objectif atteint en 1530 itérations
# objectif atteint en 1531 itérations
# objectif atteint en 1532 itérations
# objectif atteint en 1533 itérations
# objectif atteint en 1534 itérations
# objectif atteint en 1535 itérations
# objectif atteint en 1536 itérations
# objectif atteint en 1537 itérations
# objectif atteint en 1538 itérations
# objectif atteint en 1539 itérations
# objectif atteint en 1540 itérations
# objectif atteint en 1541 itérations
# objectif atteint en 1542 itérations
# objectif atteint en 1543 itérations
# objectif atteint en 1544 itérations
# objectif atteint en 1545 itérations
# objectif atteint en 1546 itérations
# objectif atteint en 1547 itérations
# objectif atteint en 1548 itérations
# objectif atteint en 1549 itérations
# objectif atteint en 1550 itérations
# objectif atteint en 1551 itérations
# objectif atteint en 1552 itérations
# objectif atteint en 1553 itérations
# objectif atteint en 1554 itérations
# objectif atteint en 1555 itérations
# objectif atteint en 1556 itérations
# objectif atteint en 1557 itérations
# objectif atteint en 1558 itérations
# objectif atteint en 1559 itérations
# objectif atteint en 1560 itérations
# objectif atteint en 1561 itérations
# objectif atteint en 1562 itérations
# objectif atteint en 1563 itérations
# objectif atteint en 1564 itérations
# objectif atteint en 1565 itérations
# objectif atteint en 1566 itérations
# objectif atteint en 1567 itérations
# objectif atteint en 1568 itérations
# objectif atteint en 1569 itérations
# objectif atteint en 1570 itérations
# objectif atteint en 1571 itérations
# objectif atteint en 1572 itérations
# objectif atteint en 1573 itérations
# objectif atteint en 1574 itérations
# objectif atteint en 1575 itérations
# objectif atteint en 1576 itérations
# objectif atteint en 1577 itérations
# objectif atteint en 1578 itérations
# objectif atteint en 1579 itérations
# objectif atteint en 1580 itérations
# objectif atteint en 1581 itérations
# objectif atteint en 1582 itérations
# objectif atteint en 1583 itérations
# objectif atteint en 1584 itérations
# objectif atteint en 1585 itérations
# objectif atteint en 1586 itérations
# objectif atteint en 1587 itérations
# objectif atteint en 1588 itérations
# objectif atteint en 1589 itérations
# objectif atteint en 1590 itérations
# objectif atteint en 1591 itérations
# objectif atteint en 1592 itérations
# objectif atteint en 1593 itérations
# objectif atteint en 1594 itérations
# objectif atteint en 1595 itérations
# objectif atteint en 1596 itérations
# objectif atteint en 1597 itérations
# objectif atteint en 1598 itérations
# objectif atteint en 1599 itérations
# objectif atteint en 1600 itérations
# objectif atteint en 1601 itérations
# objectif atteint en 1602 itérations
# objectif atteint en 1603 itérations
# objectif atteint en 1604 itérations
# objectif atteint en 1605 itérations
# objectif atteint en 1606 itérations
# objectif atteint en 1607 itérations
# objectif atteint en 1608 itérations
# objectif atteint en 1609 itérations
# objectif atteint en 1610 itérations
# objectif atteint en 1611 itérations
# objectif atteint en 1612 itérations
# objectif atteint en 1613 itérations
# objectif atteint en 1614 itérations
# objectif atteint en 1615 itérations
# objectif atteint en 1616 itérations
# objectif atteint en 1617 itérations
# objectif atteint en 1618 itérations
# objectif atteint en 1619 itérations
# objectif atteint en 1620 itérations
# objectif atteint en 1621 itérations
# objectif atteint en 1622 itérations
# objectif atteint en 1623 itérations
# objectif atteint en 1624 itérations
# objectif atteint en 1625 itérations
# objectif atteint en 1626 itérations
# objectif atteint en 1627 itérations
# objectif atteint en 1628 itérations
# objectif atteint en 1629 itérations
# objectif atteint en 1630 itérations
# objectif atteint en 1631 itérations
# objectif atteint en 1632 itérations
# objectif atteint en 1633 itérations
# objectif atteint en 1634 itérations
# objectif atteint en 1635 itérations
# objectif atteint en 1636 itérations
# objectif atteint en 1637 itérations
# objectif atteint en 1638 itérations
# objectif atteint en 1639 itérations
# objectif atteint en 1640 itérations
# objectif atteint en 1641 itérations
# objectif atteint en 1642 itérations
# objectif atteint en 1643 itérations
# objectif atteint en 1644 itérations
# objectif atteint en 1645 itérations
# objectif atteint en 1646 itérations
# objectif atteint en 1647 itérations
# objectif atteint en 1648 itérations
# objectif atteint en 1649 itérations
# objectif atteint en 1650 itérations
# objectif atteint en 1651 itérations
# objectif atteint en 1652 itérations
# objectif atteint en 1653 itérations
# objectif atteint en 1654 itérations
# objectif atteint en 1655 itérations
# objectif atteint en 1656 itérations
# objectif atteint en 1657 itérations
# objectif atteint en 1658 itérations
# objectif atteint en 1659 itérations
# objectif atteint en 1660 itérations
# objectif atteint en 1661 itérations
# objectif atteint en 1662 itérations
# objectif atteint en 1663 itérations
# objectif atteint en 1664 itérations
# objectif atteint en 1665 itérations
# objectif atteint en 1666 itérations
# objectif atteint en 1667 itérations
# objectif atteint en 1668 itérations
# objectif atteint en 1669 itérations
# objectif atteint en 1670 itérations
# objectif atteint en 1671 itérations
# objectif atteint en 1672 itérations
# objectif atteint en 1673 itérations
# objectif atteint en 1674 itérations
# objectif atteint en 1675 itérations
# objectif atteint en 1676 itérations
# objectif atteint en 1677 itérations
# objectif atteint en 1678 itérations
# objectif atteint en 1679 itérations
# objectif atteint en 1680 itérations
# objectif atteint en 1681 itérations
# objectif atteint en 1682 itérations
# objectif atteint en 1683 itérations
# objectif atteint en 1684 itérations
# objectif atteint en 1685 itérations
# objectif atteint en 1686 itérations
# objectif atteint en 1687 itérations
# objectif atteint en 1688 itérations
# objectif atteint en 1689 itérations
# objectif atteint en 1690 itérations
# objectif atteint en 1691 itérations
# objectif atteint en 1692 itérations
# objectif atteint en 1693 itérations
# objectif atteint en 1694 itérations
# objectif atteint en 1695 itérations
# objectif atteint en 1696 itérations
# objectif atteint en 1697 itérations
# objectif atteint en 1698 itérations
# objectif atteint en 1699 itérations
# objectif atteint en 1700 itérations
# objectif atteint en 1701 itérations
# objectif atteint en 1702 itérations
# objectif atteint en 1703 itérations
# objectif atteint en 1704 itérations
# objectif atteint en 1705 itérations
# objectif atteint en 1706 itérations
# objectif atteint en 1707 itérations
# objectif atteint en 1708 itérations
# objectif atteint en 1709 itérations
# objectif atteint en 1710 itérations
# objectif atteint en 1711 itérations
# objectif atteint en 1712 itérations
# objectif atteint en 1713 itérations
# objectif atteint en 1714 itérations
# objectif atteint en 1715 itérations
# objectif atteint en 1716 itérations
# objectif atteint en 1717 itérations
# objectif atteint en 1718 itérations
# objectif atteint en 1719 itérations
# objectif atteint en 1720 itérations
# objectif atteint en 1721 itérations
# objectif atteint en 1722 itérations
# objectif atteint en 1723 itérations
# objectif atteint en 1724 itérations
# objectif atteint en 1725 itérations
# objectif atteint en 1726 itérations
# objectif atteint en 1727 itérations
# objectif atteint en 1728 itérations
# objectif atteint en 1729 itérations
# objectif atteint en 1730 itérations
# objectif atteint en 1731 itérations
# objectif atteint en 1732 itérations
# objectif atteint en 1733 itérations
# objectif atteint en 1734 itérations
# objectif atteint en 1735 itérations
# objectif atteint en 1736 itérations
# objectif atteint en 1737 itérations
# objectif atteint en 1738 itérations
# objectif atteint en 1739 itérations
# objectif atteint en 1740 itérations
# objectif atteint en 1741 itérations
# objectif atteint en 1742 itérations
# objectif atteint en 1743 itérations
# objectif atteint en 1744 itérations
# objectif atteint en 1745 itérations
# objectif atteint en 1746 itérations
# objectif atteint en 1747 itérations
# objectif atteint en 1748 itérations
# objectif atteint en 1749 itérations
# objectif atteint en 1750 itérations
# objectif atteint en 1751 itérations
# objectif atteint en 1752 itérations
# objectif atteint en 1753 itérations
# objectif atteint en 1754 itérations
# objectif atteint en 1755 itérations
# objectif atteint en 1756 itérations
# objectif atteint en 1757 itérations
# objectif atteint en 1758 itérations
# objectif atteint en 1759 itérations
# objectif atteint en 1760 itérations
# objectif atteint en 1761 itérations
# objectif atteint en 1762 itérations
# objectif atteint en 1763 itérations
# objectif atteint en 1764 itérations
# objectif atteint en 1765 itérations
# objectif atteint en 1766 itérations
# objectif atteint en 1767 itérations
# objectif atteint en 1768 itérations
# objectif atteint en 1769 itérations
# objectif atteint en 1770 itérations
# objectif atteint en 1771 itérations
# objectif atteint en 1772 itérations
# objectif atteint en 1773 itérations
# objectif atteint en 1774 itérations
# objectif atteint en 1775 itérations
# objectif atteint en 1776 itérations
# objectif atteint en 1777 itérations
# objectif atteint en 1778 itérations
# objectif atteint en 1779 itérations
# objectif atteint en 1780 itérations
# objectif atteint en 1781 itérations
# objectif atteint en 1782 itérations
# objectif atteint en 1783 itérations
# objectif atteint en 1784 itérations
# objectif atteint en 1785 itérations
# objectif atteint en 1786 itérations
# objectif atteint en 1787 itérations
# objectif atteint en 1788 itérations
# objectif atteint en 1789 itérations
# objectif atteint en 1790 itérations
# objectif atteint en 1791 itérations
# objectif atteint en 1792 itérations
# objectif atteint en 1793 itérations
# objectif atteint en 1794 itérations
# objectif atteint en 1795 itérations
# objectif atteint en 1796 itérations
# objectif atteint en 1797 itérations
# objectif atteint en 1798 itérations
# objectif atteint en 1799 itérations
# objectif atteint en 1800 itérations
# objectif atteint en 1801 itérations
# objectif atteint en 1802 itérations
# objectif atteint en 1803 itérations
# objectif atteint en 1804 itérations
# objectif atteint en 1805 itérations
# objectif atteint en 1806 itérations
# objectif atteint en 1807 itérations
# objectif atteint en 1808 itérations
# objectif atteint en 1809 itérations
# objectif atteint en 1810 itérations
# objectif atteint en 1811 itérations
# objectif atteint en 1812 itérations
# objectif atteint en 1813 itérations
# objectif atteint en 1814 itérations
# objectif atteint en 1815 itérations
# objectif atteint en 1816 itérations
# objectif atteint en 1817 itérations
# objectif atteint en 1818 itérations
# objectif atteint en 1819 itérations
# objectif atteint en 1820 itérations
# objectif atteint en 1821 itérations
# objectif atteint en 1822 itérations
# objectif atteint en 1823 itérations
# objectif atteint en 1824 itérations
# objectif atteint en 1825 itérations
# objectif atteint en 1826 itérations
# objectif atteint en 1827 itérations
# objectif atteint en 1828 itérations
# objectif atteint en 1829 itérations
# objectif atteint en 1830 itérations
# objectif atteint en 1831 itérations
# objectif atteint en 1832 itérations
# objectif atteint en 1833 itérations
# objectif atteint en 1834 itérations
# objectif atteint en 1835 itérations
# objectif atteint en 1836 itérations
# objectif atteint en 1837 itérations
# objectif atteint en 1838 itérations
# objectif atteint en 1839 itérations
# objectif atteint en 1840 itérations
# objectif atteint en 1841 itérations
# objectif atteint en 1842 itérations
# objectif atteint en 1843 itérations
# objectif atteint en 1844 itérations
# objectif atteint en 1845 itérations
# objectif atteint en 1846 itérations
# objectif atteint en 1847 itérations
# objectif atteint en 1848 itérations
# objectif atteint en 1849 itérations
# objectif atteint en 1850 itérations
# objectif atteint en 1851 itérations
# objectif atteint en 1852 itérations
# objectif atteint en 1853 itérations
# objectif atteint en 1854 itérations
# objectif atteint en 1855 itérations
# objectif atteint en 1856 itérations
# objectif atteint en 1857 itérations
# objectif atteint en 1858 itérations
# objectif atteint en 1859 itérations
# objectif atteint en 1860 itérations
# objectif atteint en 1861 itérations
# objectif atteint en 1862 itérations
# objectif atteint en 1863 itérations
# objectif atteint en 1864 itérations
# objectif atteint en 1865 itérations
# objectif atteint en 1866 itérations
# objectif atteint en 1867 itérations
# objectif atteint en 1868 itérations
# objectif atteint en 1869 itérations
# objectif atteint en 1870 itérations
# objectif atteint en 1871 itérations
# objectif atteint en 1872 itérations
# objectif atteint en 1873 itérations
# objectif atteint en 1874 itérations
# objectif atteint en 1875 itérations
# objectif atteint en 1876 itérations
# objectif atteint en 1877 itérations
# objectif atteint en 1878 itérations
# objectif atteint en 1879 itérations
# objectif atteint en 1880 itérations
# objectif atteint en 1881 itérations
# objectif atteint en 1882 itérations
# objectif atteint en 1883 itérations
# objectif atteint en 1884 itérations
# objectif atteint en 1885 itérations
# objectif atteint en 1886 itérations
# objectif atteint en 1887 itérations
# objectif atteint en 1888 itérations
# objectif atteint en 1889 itérations
# objectif atteint en 1890 itérations
# objectif atteint en 1891 itérations
# objectif atteint en 1892 itérations
# objectif atteint en 1893 itérations
# objectif atteint en 1894 itérations
# objectif atteint en 1895 itérations
# objectif atteint en 1896 itérations
# objectif atteint en 1897 itérations
# objectif atteint en 1898 itérations
# objectif atteint en 1899 itérations
# objectif atteint en 1900 itérations
# objectif atteint en 1901 itérations
# objectif atteint en 1902 itérations
# objectif atteint en 1903 itérations
# objectif atteint en 1904 itérations
# objectif atteint en 1905 itérations
# objectif atteint en 1906 itérations
# objectif atteint en 1907 itérations
# objectif atteint en 1908 itérations
# objectif atteint en 1909 itérations
# objectif atteint en 1910 itérations
# objectif atteint en 1911 itérations
# objectif atteint en 1912 itérations
# objectif atteint en 1913 itérations
# objectif atteint en 1914 itérations
# objectif atteint en 1915 itérations
# objectif atteint en 1916 itérations
# objectif atteint en 1917 itérations
# objectif atteint en 1918 itérations
# objectif atteint en 1919 itérations
# objectif atteint en 1920 itérations
# objectif atteint en 1921 itérations
# objectif atteint en 1922 itérations
# objectif atteint en 1923 itérations
# objectif atteint en 1924 itérations
# objectif atteint en 1925 itérations
# objectif atteint en 1926 itérations
# objectif atteint en 1927 itérations
# objectif atteint en 1928 itérations
# objectif atteint en 1929 itérations
# objectif atteint en 1930 itérations
# objectif atteint en 1931 itérations
# objectif atteint en 1932 itérations
# objectif atteint en 1933 itérations
# objectif atteint en 1934 itérations
# objectif atteint en 1935 itérations
# objectif atteint en 1936 itérations
# objectif atteint en 1937 itérations
# objectif atteint en 1938 itérations
# objectif atteint en 1939 itérations
# objectif atteint en 1940 itérations
# objectif atteint en 1941 itérations
# objectif atteint en 1942 itérations
# objectif atteint en 1943 itérations
# objectif atteint en 1944 itérations
# objectif atteint en 1945 itérations
# objectif atteint en 1946 itérations
# objectif atteint en 1947 itérations
# objectif atteint en 1948 itérations
# objectif atteint en 1949 itérations
# objectif atteint en 1950 itérations
# objectif atteint en 1951 itérations
# objectif atteint en 1952 itérations
# objectif atteint en 1953 itérations
# objectif atteint en 1954 itérations
# objectif atteint en 1955 itérations
# objectif atteint en 1956 itérations
# objectif atteint en 1957 itérations
# objectif atteint en 1958 itérations
# objectif atteint en 1959 itérations
# objectif atteint en 1960 itérations
# objectif atteint en 1961 itérations
# objectif atteint en 1962 itérations
# objectif atteint en 1963 itérations
# objectif atteint en 1964 itérations
# objectif atteint en 1965 itérations
# objectif atteint en 1966 itérations
# objectif atteint en 1967 itérations
# objectif atteint en 1968 itérations
# objectif atteint en 1969 itérations
# objectif atteint en 1970 itérations
# objectif atteint en 1971 itérations
# objectif atteint en 1972 itérations
# objectif atteint en 1973 itérations
# objectif atteint en 1974 itérations
# objectif atteint en 1975 itérations
# objectif atteint en 1976 itérations
# objectif atteint en 1977 itérations
# objectif atteint en 1978 itérations
# objectif atteint en 1979 itérations
# objectif atteint en 1980 itérations
# objectif atteint en 1981 itérations
# objectif atteint en 1982 itérations
# objectif atteint en 1983 itérations
# objectif atteint en 1984 itérations
# objectif atteint en 1985 itérations
# objectif atteint en 1986 itérations
# objectif atteint en 1987 itérations
# objectif atteint en 1988 itérations
# objectif atteint en 1989 itérations
# objectif atteint en 1990 itérations
# objectif atteint en 1991 itérations
# objectif atteint en 1992 itérations
# objectif atteint en 1993 itérations
# objectif atteint en 1994 itérations
# objectif atteint en 1995 itérations
# objectif atteint en 1996 itérations
# objectif atteint en 1997 itérations
# objectif atteint en 1998 itérations

# %%
plt.plot(np.linspace(0,1,nx), xk[:,nstep-1],'+')
plt.plot(np.linspace(0,1,nx),x_dagger)
