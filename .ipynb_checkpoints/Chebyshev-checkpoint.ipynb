# %%
# general
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.linalg import inv,pinvh,eig,eigh
from scipy.stats import linregress
# %matplotlib inline
import numpy.polynomial.chebyshev as che
# local
from FBResNet.myfunc import Physics

# %%
a     = 1/2
noise = 0.05

# %%
# Matrice opérateur
nx  = 2000
dx  = 1/nx
m   = 500
T   = dx*np.tri(nx)

# %%
Ta = np.zeros((nx,nx))
for i in range(nx):
    for j in range(nx):
        if j<=i:
            Ta[i,j]=1/a*dx**(a)*((i-j+1)**a-(i-j)**a)

# %%
t   = np.linspace(0,1-1/nx,nx)
x   = np.exp(-(t-0.5)**2/0.1**2)
x   = x/np.amax(x)
y   = Ta.dot(x)

# %%
# noise
m = 500
physics     = Physics(nx,m)
vn          = np.zeros(m)
fmax        = 400
vn[fmax:]   = np.random.randn(m-fmax)
vn_elt      = physics.BasisChangeInv(vn)
vn_elt      = vn_elt/np.linalg.norm(vn_elt)
yd          = y + noise*np.linalg.norm(y)*vn_elt

# %%
# cheb
nc   = 50
yd_che = che.chebfit(t,yd,nc-1)
x_che = che.chebfit(t,x,nc-1)
pol = np.zeros((nc,nc))
fac = 1/a
for j in range(nc):
    pol[:,j]=fac*che.chebfit(t,t**(a+i),nc-1)
    fac*=(j+1)/(a+j+1)
# Out:
# 1.3333333333333333
# 1.0666666666666667
# 0.9142857142857143
# 0.8126984126984126
# 0.7388167388167387
# 0.6819846819846819
# 0.6365190365190364
# 0.5990767402532108
# 0.5675463855030418
# 0.5405203671457541
# 0.5170194816176779
# 0.49633870235297073
# 0.4779557874510088
# 0.46147455340097404
# 0.4465882774848136
# 0.4330552993792132
# 0.4206822908255214
# 0.4093124991815884
# 0.398817306894881
# 0.38909005550720094
# 0.380041449565173
# 0.37159608401928024
# 0.36368978435929555
# 0.3562675438621671
# 0.3492819057472226
# 0.3426916811104826
# 0.3364609232721102
# 0.33055810005680997
# 0.32495542039483016
# 0.31962828235557067
# 0.3145548175562759
# 0.3097155126707947
# 0.3050928930786933
# 0.30067125694711805
# 0.2964364505112432
# 0.2923756772165686
# 0.28847733485368104
# 0.2847308759594774
# 0.28112668765619286
# 0.2776559878085855
# 0.27431073494342184
# 0.2710835498264404
# 0.26796764695487213
# 0.2649567745171769
# 0.26204516161039476
# 0.25922747170060556
# 0.25649876147217815
# 0.253854444343599
# 0.251290258037098
# 0.24880223568029503
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/polynomial/chebyshev.py:1663: RankWarning: The fit may be poorly conditioned
#   return pu._fit(chebvander, x, y, deg, rcond, full, w)

# %%
plt.plot(yd_che)
plt.plot(pol.dot(x_che))
