# %%
# importation
import numpy as np
import matplotlib.pyplot as plt
import torch
import matplotlib.pyplot as plt
# %matplotlib inline
# local
from FBResNet.myfunc import Physics
from FBResNet.main import FBRestNet
from FBResNet.model import MyModel

# %%
exp1 = FBRestNet(experimentation=Physics(2000,50,1,1), nb_blocks=20, noise = 0.1,\
                 folder = './', im_set="Set1",batch_size=[200,1],\
                 lr=1e-3, nb_epochs=[20,1])

# %%
train_set, val_set = exp1.CreateDataSet()

# %%
exp1.train(train_set,val_set)
# Out:
# epoch :  0  -----  validation :  7.084256557473881e-05
# [0.00081764] [0.04368977]
# [0.00081764] [0.04368971]
# [0.00081764] [0.04368968]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368957]
# [0.00081775] [0.04369521]
# [0.00082366] [0.04400415]
# -----------------------------------------------------------------
# Training is done.
# -----------------------------------------------------------------
# Final Lipschitz constant =  0.0007784658659290907

# %%
exp1.test(val_set)
# Out:
# Erreur relative :  0.004863412072871243

# %%
exp1.model.Lipschitz()
# Out:
# [0.00081764] [0.04368977]
# [0.00081764] [0.04368971]
# [0.00081764] [0.04368968]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368965]
# [0.00081764] [0.04368966]
# [0.00081764] [0.04368957]
# [0.00081775] [0.04369521]
# [0.00082366] [0.04400415]
# 0.0007784658659290907
