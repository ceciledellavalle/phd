# %%
# importation
import numpy as np
from torch.autograd import Variable
import torch
import matplotlib.pyplot as plt
# %matplotlib inline
# local
from FBResNet.myfunc import Physics
from FBResNet.myfunc import MyMatmul
from FBResNet.main import FBRestNet
from FBResNet.model import MyModel
from FBResNet.posttreat import Export_hyper

# %%
exp1 = FBRestNet(experimentation=Physics(2000,50,0.5,1), constraint = 'slab',\
                 nb_blocks=20, noise = 0.1,\
                 folder = './', im_set="Set1",batch_size=[60,1],\
                 lr=1e-3, nb_epochs=[10,1])

# %%
train_set, val_set = exp1.CreateDataSet()

# %%
exp1.train(train_set,val_set,save_model=True)
# Out:
# epoch :  0  -----  validation :  0.0003137551822491284
# epoch :  1  -----  validation :  0.00030926344793682034
# epoch :  2  -----  validation :  0.00030521838810895324
# epoch :  3  -----  validation :  0.0003007118675189926
# epoch :  4  -----  validation :  0.0002965130705361892
# epoch :  5  -----  validation :  0.000292212234374969
# epoch :  6  -----  validation :  0.00028811834789322396
# epoch :  7  -----  validation :  0.0002840687103391821
# epoch :  8  -----  validation :  0.0002798461516105913
# epoch :  9  -----  validation :  0.00027573262310684905
# -----------------------------------------------------------------
# Training is done.
# -----------------------------------------------------------------
# Final Lipschitz constant =  1.6256478364439578e-16

# %% [markdown]
# ### Gaussian

# %%
exp1.test_gauss()

# %% [markdown]
# ### Lipschitz

# %%
exp1.model.Lipschitz(opt1="semi",opt2="entree11")
# Out:
# 2.4570096837225405e-15

# %%
exp1.model.Lipschitz(opt1="semi",opt2="entree01")
# Out:
# 1.5817484912687273e-16

# %% [markdown]
# ### Testing set

# %%
l_i, l_t, l_p = exp1.test(val_set)
# Out:
# Erreur relative :  0.10395605787088144

# %%
exp1.model.Lipschitz(opt1="semi",opt2="entree11")
# Out:
# 2.5950689113031146e-15

# %%
exp1.model.Lipschitz(opt1="semi",opt2="entree01")
# Out:
# 1.6256478364439578e-16
