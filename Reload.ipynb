# %%
# importation
import numpy as np
from torch.autograd import Variable
import torch
import matplotlib.pyplot as plt
# %matplotlib inline
# local
from FBResNet.myfunc import Physics
from FBResNet.myfunc import MyMatmul
from FBResNet.main import FBRestNet
from FBResNet.model import MyModel
from FBResNet.posttreat import Export_hyper

# %% [markdown]
# ### a=1

# %%
exp1 = FBRestNet(experimentation=Physics(2000,50,1,1), nb_blocks=20, noise = 0.01,\
                 folder = './', im_set="Set1",batch_size=[600,1],\
                 lr=1e-3, nb_epochs=[30,1])

# %%
#exp1.LoadParam()

# %%
exp1.test_gauss(noise=0.01)
# Out:
# x-xp/x = 0.12516017800648346

# %%
exp2 = FBRestNet(experimentation=Physics(2000,50,1,1), nb_blocks=20, noise = 0.05,\
                 folder = './', im_set="Set1",batch_size=[600,1],\
                 lr=1e-3, nb_epochs=[30,1])
exp2.LoadParam()
exp2.test_gauss(noise=0.05)
# Out:
# x-xp/x = 0.12755833484566242

# %% [markdown]
# ### a=1/2

# %%
exp3 = FBRestNet(experimentation=Physics(2000,50,0.5,1), constraint = 'cube',\
                 nb_blocks=20, noise = 0.05,\
                 folder = './', im_set="Set1",batch_size=[600,1],\
                 lr=1e-3, nb_epochs=[30,1])
exp3.LoadParam()
exp3.test_gauss(noise=0.05)
# Out:
# x-xp/x = 0.08816476581998223

# %%
exp3.test_gauss(noise=0.1)
# Out:
# x-xp/x = 0.1262673819100363

# %%
exp3.test_gauss(noise=0.01)
# Out:
# x-xp/x = 0.07509459517118128
